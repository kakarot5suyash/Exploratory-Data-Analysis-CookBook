# %% [markdown]
# # Appending Data into a dataset

# %% [markdown]
# ## Importing pandas

# %%
import pandas as pd

# %% [markdown]
# ## Loading datasets and including relevant columns

# %%
marketing_sample1 = pd.read_csv('Data/marketing_campaign_append1.csv')
marketing_sample2 = pd.read_csv('Data/marketing_campaign_append2.csv')
marketing_sample1 = marketing_sample1[['ID', 'Year_Birth','Education','Marital_Status','Income','Kidhome','Teenhome','Dt_Customer','Recency','NumStorePurchases', 'NumWebVisitsMonth']]

marketing_sample2 = marketing_sample2[['ID', 'Year_Birth','Education','Marital_Status','Income','Kidhome','Teenhome','Dt_Customer','Recency','NumStorePurchases', 'NumWebVisitsMonth']]

# %%
marketing_sample1.head(10).T
# Out:
#                             0           1           2           3           4  \
# ID                       5524        2174        4141        6182        5324
# Year_Birth               1957        1954        1965        1984        1981
# Education          Graduation  Graduation  Graduation  Graduation         PhD
# Marital_Status         Single      Single    Together    Together     Married
# Income                58138.0     46344.0     71613.0     26646.0     58293.0
# Kidhome                     0           1           0           1           1
# Teenhome                    0           1           0           0           0
# Dt_Customer        04/09/2012  08/03/2014  21/08/2013  10/02/2014  19/01/2014
# Recency                    58          38          26          26          94
# NumStorePurchases           4           2          10           4           6
# NumWebVisitsMonth           7           5           4           6           5
#
#                             5           6           7           8           9
# ID                       7446         965        6177        4855        5899
# Year_Birth               1967        1971        1985        1974        1950
# Education              Master  Graduation         PhD         PhD         PhD
# Marital_Status       Together    Divorced     Married    Together    Together
# Income                62513.0     55635.0     33454.0     30351.0      5648.0
# Kidhome                     0           0           1           1           1
# Teenhome                    1           1           0           0           1
# Dt_Customer        09/09/2013  13/11/2012  08/05/2013  06/06/2013  13/03/2014
# Recency                    16          34          32          19          68
# NumStorePurchases          10           7           4           2           0
# NumWebVisitsMonth           6           6           8           9          20

# %%
marketing_sample2.head(10)
# Out:
#       ID  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0   9135        1950  Graduation       Together   27203        1         1
# 1    466        1944  Graduation        Married   65275        0         0
# 2   9135        1950  Graduation       Together   27203        1         1
# 3  10623        1961      Master       Together   48330        0         1
# 4   8151        1990       Basic        Married   24279        0         0
# 5   5140        1985         PhD        Married   64355        1         0
# 6  10160        1956      Master       Together   50943        0         1
# 7   4945        1953  Graduation          Widow   53653        0         0
# 8  10584        1976  Graduation        Married   65665        0         1
# 9   6071        1989  Graduation         Single   81217        0         0
#
#   Dt_Customer  Recency  NumStorePurchases  NumWebVisitsMonth
# 0  06/08/2012       92                  2                  8
# 1  03/04/2013        9                 13                  2
# 2  06/08/2012       92                  2                  8
# 3  15/11/2013        2                  3                  5
# 4  29/12/2012        6                  3                  8
# 5  24/08/2012       66                 12                  8
# 6  21/06/2013       49                  3                  5
# 7  07/11/2012       29                 12                  6
# 8  02/12/2013       77                  8                  3
# 9  19/07/2013       77                 11                  1

# %%
marketing_sample1.dtypes
# Out:
# ID                     int64
# Year_Birth             int64
# Education             object
# Marital_Status        object
# Income               float64
# Kidhome                int64
# Teenhome               int64
# Dt_Customer           object
# Recency                int64
# NumStorePurchases      int64
# NumWebVisitsMonth      int64
# dtype: object

# %%
marketing_sample2.dtypes
# Out:
# ID                    int64
# Year_Birth            int64
# Education            object
# Marital_Status       object
# Income                int64
# Kidhome               int64
# Teenhome              int64
# Dt_Customer          object
# Recency               int64
# NumStorePurchases     int64
# NumWebVisitsMonth     int64
# dtype: object

# %%
marketing_sample1.shape
# Out:
# (500, 11)

# %%
marketing_sample2.shape
# Out:
# (500, 11)

# %% [markdown]
# ## Appending the datasets using the concat method

# %%
appended_data = pd.concat([marketing_sample1, marketing_sample2])

# %%
appended_data.head(10)
# Out:
#      ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0  5524        1957  Graduation         Single  58138.0        0         0
# 1  2174        1954  Graduation         Single  46344.0        1         1
# 2  4141        1965  Graduation       Together  71613.0        0         0
# 3  6182        1984  Graduation       Together  26646.0        1         0
# 4  5324        1981         PhD        Married  58293.0        1         0
# 5  7446        1967      Master       Together  62513.0        0         1
# 6   965        1971  Graduation       Divorced  55635.0        0         1
# 7  6177        1985         PhD        Married  33454.0        1         0
# 8  4855        1974         PhD       Together  30351.0        1         0
# 9  5899        1950         PhD       Together   5648.0        1         1
#
#   Dt_Customer  Recency  NumStorePurchases  NumWebVisitsMonth
# 0  04/09/2012       58                  4                  7
# 1  08/03/2014       38                  2                  5
# 2  21/08/2013       26                 10                  4
# 3  10/02/2014       26                  4                  6
# 4  19/01/2014       94                  6                  5
# 5  09/09/2013       16                 10                  6
# 6  13/11/2012       34                  7                  6
# 7  08/05/2013       32                  4                  8
# 8  06/06/2013       19                  2                  9
# 9  13/03/2014       68                  0                 20

# %%
appended_data.dtypes
# Out:
# ID                     int64
# Year_Birth             int64
# Education             object
# Marital_Status        object
# Income               float64
# Kidhome                int64
# Teenhome               int64
# Dt_Customer           object
# Recency                int64
# NumStorePurchases      int64
# NumWebVisitsMonth      int64
# dtype: object

# %%
appended_data.shape
# Out:
# (1000, 11)

# %%
appended_data.tail(10).T
# Out:
#                           490         491         492         493         494  \
# ID                       9305         453        8545        9850        7378
# Year_Birth               1976        1956        1954        1972        1981
# Education            2n Cycle         PhD  Graduation    2n Cycle      Master
# Marital_Status         Single       Widow    Divorced     Married    Together
# Income                79689.0     35340.0     85683.0     24884.0     42021.0
# Kidhome                     0           1           0           1           1
# Teenhome                    0           1           0           0           0
# Dt_Customer        12/05/2013  29/06/2014  21/03/2014  29/11/2012  31/08/2012
# Recency                    65           1           6          32          34
# NumStorePurchases          13           3          10           3           6
# NumWebVisitsMonth           2           5           1           7           9
#
#                           495         496         497         498         499
# ID                       7646        1640        5184        8492       11188
# Year_Birth               1989        1954        1995        1978        1957
# Education          Graduation  Graduation  Graduation  Graduation  Graduation
# Marital_Status         Single    Divorced      Single    Together    Together
# Income                64449.0     64587.0     34824.0     75437.0     26091.0
# Kidhome                     1           1           0           0           1
# Teenhome                    0           1           0           0           1
# Dt_Customer        18/02/2014  22/06/2014  26/03/2014  09/11/2013  25/02/2014
# Recency                    70          49          65          25          84
# NumStorePurchases          12           4           2          10           3
# NumWebVisitsMonth           4           3           6           6           5
